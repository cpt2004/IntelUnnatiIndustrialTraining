# %%
from keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

# %%
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
print('Train: X = ', trainX.shape)
print('Test: X = ', testX.shape)
# Out:
# Train: X =  (60000, 28, 28)
# Test: X =  (10000, 28, 28)

# %%
for i in range(1, 10):
	plt.subplot(3, 3, i)
	plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
plt.show()

# %%
trainX = np.expand_dims(trainX, -1)
testX = np.expand_dims(testX, -1)

print(trainX.shape)
# Out:
# (60000, 28, 28, 1)

# %%
def model_arch():
	models = Sequential()	
	models.add(Conv2D(64, (5, 5),
					padding="same",
					activation="relu",
					input_shape=(28, 28, 1)))
	
	models.add(MaxPooling2D(pool_size=(2, 2)))
	models.add(Conv2D(128, (5, 5), padding="same",
					activation="relu"))
	
	models.add(MaxPooling2D(pool_size=(2, 2)))
	models.add(Conv2D(256, (5, 5), padding="same",
					activation="relu"))
	
	models.add(MaxPooling2D(pool_size=(2, 2)))
	
	models.add(Flatten())
	models.add(Dense(256, activation="relu"))
	
	models.add(Dense(10, activation="softmax"))
	return models

# %%
model = model_arch()

model.compile(optimizer=Adam(learning_rate=1e-3),
			loss='sparse_categorical_crossentropy',
			metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        1664
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 128)       204928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         819456
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 256)               590080
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,618,698
# Trainable params: 1,618,698
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
	trainX.astype(np.float32), trainy.astype(np.float32),
	epochs=10,
	steps_per_epoch=100,
	validation_split=0.33
)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 61s 595ms/step - loss: 3.2756 - sparse_categorical_accuracy: 0.7007 - val_loss: 0.4255 - val_sparse_categorical_accuracy: 0.8414
# Epoch 2/10
# 100/100 [==============================] - 57s 576ms/step - loss: 0.3804 - sparse_categorical_accuracy: 0.8611 - val_loss: 0.3499 - val_sparse_categorical_accuracy: 0.8730
# Epoch 3/10
# 100/100 [==============================] - 63s 627ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3277 - val_sparse_categorical_accuracy: 0.8810
# Epoch 4/10
# 100/100 [==============================] - 57s 576ms/step - loss: 0.2751 - sparse_categorical_accuracy: 0.8994 - val_loss: 0.3063 - val_sparse_categorical_accuracy: 0.8914
# Epoch 5/10
# 100/100 [==============================] - 55s 555ms/step - loss: 0.2519 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.2869 - val_sparse_categorical_accuracy: 0.8959
# Epoch 6/10
# 100/100 [==============================] - 53s 528ms/step - loss: 0.2209 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.2728 - val_sparse_categorical_accuracy: 0.9023
# Epoch 7/10
# 100/100 [==============================] - 56s 558ms/step - loss: 0.2051 - sparse_categorical_accuracy: 0.9244 - val_loss: 0.2763 - val_sparse_categorical_accuracy: 0.9010
# Epoch 8/10
# 100/100 [==============================] - 57s 574ms/step - loss: 0.1836 - sparse_categorical_accuracy: 0.9311 - val_loss: 0.2626 - val_sparse_categorical_accuracy: 0.9059
# Epoch 9/10
# 100/100 [==============================] - 63s 628ms/step - loss: 0.1709 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.2760 - val_sparse_categorical_accuracy: 0.9034
# Epoch 10/10
# 100/100 [==============================] - 54s 539ms/step - loss: 0.1583 - sparse_categorical_accuracy: 0.9416 - val_loss: 0.2686 - val_sparse_categorical_accuracy: 0.9072

# %%
model.save_weights('./model.h5', overwrite=True)

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
labels = ['t_shirt', 'trouser', 'pullover', 'dress', 'coat',
		'sandal', 'shirt', 'sneaker', 'bag', 'ankle_boots']

predictions = model.predict(testX[:1])
label = labels[np.argmax(predictions)]

print(label)
plt.imshow(testX[:1][0])
plt.show()
# Out:
# 1/1 [==============================] - 0s 355ms/step
# ankle_boots
